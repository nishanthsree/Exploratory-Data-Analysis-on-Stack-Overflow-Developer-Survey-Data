# %%
import pandas as pd

# %%
df = pd.read_csv('data/survey_results_public.csv', index_col='Respondent')

# %%
df.shape
# Out:
# (88883, 84)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 88883 entries, 1 to 88863
# Data columns (total 84 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   MainBranch              88331 non-null  object
#  1   Hobbyist                88883 non-null  object
#  2   OpenSourcer             88883 non-null  object
#  3   OpenSource              86842 non-null  object
#  4   Employment              87181 non-null  object
#  5   Country                 88751 non-null  object
#  6   Student                 87014 non-null  object
#  7   EdLevel                 86390 non-null  object
#  8   UndergradMajor          75614 non-null  object
#  9   EduOther                84260 non-null  object
#  10  OrgSize                 71791 non-null  object
#  11  DevType                 81335 non-null  object
#  12  YearsCode               87938 non-null  object
#  13  Age1stCode              87634 non-null  object
# ...

# %%
pd.set_option('display.max_rows', 85)

# %%
df
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
# 4                              I am a developer by profession       No
# 5                              I am a developer by profession      Yes
# ...                                                       ...      ...
# 88377                                                     NaN      Yes
# 88601                                                     NaN       No
# 88802                                                     NaN       No
# 88816                                                     NaN       No
# 88863                                                     NaN      Yes
#
#                                                   OpenSourcer  \
# Respondent
# ...

# %%
df['ConvertedComp'].head(15)
# Out:
# Respondent
# 1          NaN
# 2          NaN
# 3       8820.0
# 4      61000.0
# 5          NaN
# 6     366420.0
# 7          NaN
# 8          NaN
# 9      95179.0
# 10     13293.0
# 11         NaN
# 12         NaN
# 13     90000.0
# 14     57060.0
# 15         NaN
# Name: ConvertedComp, dtype: float64

# %%
df['ConvertedComp'].median()
# Out:
# 57287.0

# %%
df.median()
# Out:
# /tmp/ipykernel_8843/530051474.py:1: FutureWarning: The default value of numeric_only in DataFrame.median is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.median()
# CompTotal        62000.0
# ConvertedComp    57287.0
# WorkWeekHrs         40.0
# CodeRevHrs           4.0
# Age                 29.0
# dtype: float64

# %%
df.describe()
# Out:
#           CompTotal  ConvertedComp   WorkWeekHrs    CodeRevHrs           Age
# count  5.594500e+04   5.582300e+04  64503.000000  49790.000000  79210.000000
# mean   5.519014e+11   1.271107e+05     42.127197      5.084308     30.336699
# std    7.331926e+13   2.841523e+05     37.287610      5.513931      9.178390
# min    0.000000e+00   0.000000e+00      1.000000      0.000000      1.000000
# 25%    2.000000e+04   2.577750e+04     40.000000      2.000000     24.000000
# 50%    6.200000e+04   5.728700e+04     40.000000      4.000000     29.000000
# 75%    1.200000e+05   1.000000e+05     44.750000      6.000000     35.000000
# max    1.000000e+16   2.000000e+06   4850.000000     99.000000     99.000000

# %%
df['ConvertedComp'].count()
# Out:
# 55823

# %%
df['Hobbyist'].value_counts()
# Out:
# Yes    71257
# No     17626
# Name: Hobbyist, dtype: int64

# %%
df['SocialMedia']
# Out:
# Respondent
# 1          Twitter
# 2        Instagram
# 3           Reddit
# 4           Reddit
# 5         Facebook
#            ...
# 88377      YouTube
# 88601          NaN
# 88802          NaN
# 88816          NaN
# 88863     WhatsApp
# Name: SocialMedia, Length: 88883, dtype: object

# %%
df['SocialMedia'].value_counts(normalize=True)
# Out:
# Reddit                      0.170233
# YouTube                     0.163791
# WhatsApp                    0.158071
# Facebook                    0.156069
# Twitter                     0.134988
# Instagram                   0.074150
# I don't use social media    0.065777
# LinkedIn                    0.053306
# WeChat 微信                   0.007899
# Snapchat                    0.007437
# VK ВКонта́кте               0.007141
# Weibo 新浪微博                  0.000663
# Youku Tudou 优酷              0.000249
# Hello                       0.000225
# Name: SocialMedia, dtype: float64

# %%
df['Country'].value_counts()
# Out:
# United States        20949
# India                 9061
# Germany               5866
# United Kingdom        5737
# Canada                3395
#                      ...
# Tonga                    1
# Timor-Leste              1
# North Korea              1
# Brunei Darussalam        1
# Chad                     1
# Name: Country, Length: 179, dtype: int64

# %%
c_group = df.groupby(['Country'])

# %%
c_group.get_group('India')
# Out:
#                                         MainBranch Hobbyist  \
# Respondent
# 8                      I code primarily as a hobby      Yes
# 10                  I am a developer by profession      Yes
# 15          I am a student who is learning to code      Yes
# 50                  I am a developer by profession      Yes
# 65                  I am a developer by profession      Yes
# ...                                            ...      ...
# 77339                                          NaN      Yes
# 79795                                          NaN      Yes
# 83862                                          NaN      Yes
# 84299                                          NaN      Yes
# 86012                                          NaN      Yes
#
#                                                   OpenSourcer  \
# Respondent
# 8                                     Less than once per year
# 10                                 Once a month or more often
# ...

# %%
fitl =df['Country']=='India'
df.loc[fitl]['SocialMedia'].value_counts()
# Out:
# WhatsApp                    2990
# YouTube                     1820
# LinkedIn                     955
# Facebook                     841
# Instagram                    822
# Twitter                      542
# Reddit                       473
# I don't use social media     250
# Snapchat                      23
# Hello                          5
# WeChat 微信                      5
# VK ВКонта́кте                  4
# Youku Tudou 优酷                 2
# Weibo 新浪微博                     1
# Name: SocialMedia, dtype: int64

# %%
c_group['SocialMedia'].value_counts(normalize=True).loc['India']
# Out:
# SocialMedia
# WhatsApp                    0.342379
# YouTube                     0.208405
# LinkedIn                    0.109355
# Facebook                    0.096301
# Instagram                   0.094126
# Twitter                     0.062063
# Reddit                      0.054162
# I don't use social media    0.028627
# Snapchat                    0.002634
# Hello                       0.000573
# WeChat 微信                   0.000573
# VK ВКонта́кте               0.000458
# Youku Tudou 优酷              0.000229
# Weibo 新浪微博                  0.000115
# Name: SocialMedia, dtype: float64

# %%
c_group['ConvertedComp'].median().loc['China']
# Out:
# 28464.0

# %%
c_group['ConvertedComp'].agg(['median','mean']).loc['India']
# Out:
# median    10080.000000
# mean      28057.664916
# Name: India, dtype: float64

# %%
filt =df['Country']== 'India'
df.loc[filt]['LanguageWorkedWith'].str.contains('Python').sum()
# Out:
# 3105

# %%
c_group['LanguageWorkedWith'].apply(lambda x: x.str.contains('Python').sum())
# Out:
# Country
# Afghanistan                              8
# Albania                                 23
# Algeria                                 40
# Andorra                                  0
# Angola                                   2
#                                         ..
# Venezuela, Bolivarian Republic of...    28
# Viet Nam                                78
# Yemen                                    3
# Zambia                                   4
# Zimbabwe                                14
# Name: LanguageWorkedWith, Length: 179, dtype: int64

# %%
country_respondents = df['Country'].value_counts()

# %%
country_uses_python = c_group['LanguageWorkedWith'].apply(lambda x: x.str.contains('Python').sum())

# %%
python_df = pd.concat([country_respondents , country_uses_python], axis='columns', sort=False)

# %%
c_resp = df['Country'].value_counts()
c_use_p = c_group['LanguageWorkedWith'].apply(lambda x: x.str.contains('Java').sum())

# %%
c_use_p.loc['India']
# Out:
# 7275

# %%
java = pd.concat([c_resp , c_use_p], axis='columns' )

# %%
java
# Out:
#                    Country  LanguageWorkedWith
# United States        20949               16640
# India                 9061                7275
# Germany               5866                4549
# United Kingdom        5737                4454
# Canada                3395                2690
# ...                    ...                 ...
# Tonga                    1                   0
# Timor-Leste              1                   1
# North Korea              1                   1
# Brunei Darussalam        1                   1
# Chad                     1                   1
#
# [179 rows x 2 columns]

# %%
java.rename(columns={'Country':'respondents','LanguageWorkedWith':'java_users'} ,inplace=True)

# %%
java
# Out:
#                    respondents  java_users
# United States            20949       16640
# India                     9061        7275
# Germany                   5866        4549
# United Kingdom            5737        4454
# Canada                    3395        2690
# ...                        ...         ...
# Tonga                        1           0
# Timor-Leste                  1           1
# North Korea                  1           1
# Brunei Darussalam            1           1
# Chad                         1           1
#
# [179 rows x 2 columns]

# %%
java.loc['India']
# Out:
# respondents    9061
# java_users     7275
# Name: India, dtype: int64

# %%
java['pct']=(java['java_users']/java['respondents'])*100

# %%
java
# Out:
#                    respondents  java_users         pct
# United States            20949       16640   79.430999
# India                     9061        7275   80.289151
# Germany                   5866        4549   77.548585
# United Kingdom            5737        4454   77.636395
# Canada                    3395        2690   79.234168
# ...                        ...         ...         ...
# Tonga                        1           0    0.000000
# Timor-Leste                  1           1  100.000000
# North Korea                  1           1  100.000000
# Brunei Darussalam            1           1  100.000000
# Chad                         1           1  100.000000
#
# [179 rows x 3 columns]

# %%
 java.sort_values(by="java_users", ascending=False)
# Out:
#                        respondents  java_users         pct
# United States                20949       16640   79.430999
# India                         9061        7275   80.289151
# Germany                       5866        4549   77.548585
# United Kingdom                5737        4454   77.636395
# Canada                        3395        2690   79.234168
# ...                            ...         ...         ...
# Chad                             1           1  100.000000
# Sao Tome and Principe            1           0    0.000000
# Tonga                            1           0    0.000000
# Liberia                          2           0    0.000000
# Djibouti                         2           0    0.000000
#
# [179 rows x 3 columns]

# %%
c = df['Country'].value_counts()
clan =  c_group['LanguageWorkedWith'].apply(lambda x: x.str.contains('C').sum())

# %%
clan.loc['India']
# Out:
# 7040

# %%
clang = pd.concat([c,clan], axis='columns')

# %%
clang
# Out:
#                    Country  LanguageWorkedWith
# United States        20949               17348
# India                 9061                7040
# Germany               5866                4710
# United Kingdom        5737                4774
# Canada                3395                2821
# ...                    ...                 ...
# Tonga                    1                   1
# Timor-Leste              1                   1
# North Korea              1                   1
# Brunei Darussalam        1                   1
# Chad                     1                   1
#
# [179 rows x 2 columns]

# %%
jlcan = c_group['LanguageWorkedWith'].apply(lambda x: x.str.contains('JavaScript').sum())

# %%
jlcan.loc[['India',"China"]]
# Out:
# Country
# India    5697
# China     349
# Name: LanguageWorkedWith, dtype: int64

# %%
df.dropna(axis= 'index', how="all")
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
# 4                              I am a developer by profession       No
# 5                              I am a developer by profession      Yes
# ...                                                       ...      ...
# 88377                                                     NaN      Yes
# 88601                                                     NaN       No
# 88802                                                     NaN       No
# 88816                                                     NaN       No
# 88863                                                     NaN      Yes
#
#                                                   OpenSourcer  \
# Respondent
# ...

# %%
import numpy as pd

# %%
df.fillna('unavaliablke')
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
# 4                              I am a developer by profession       No
# 5                              I am a developer by profession      Yes
# ...                                                       ...      ...
# 88377                                            unavaliablke      Yes
# 88601                                            unavaliablke       No
# 88802                                            unavaliablke       No
# 88816                                            unavaliablke       No
# 88863                                            unavaliablke      Yes
#
#                                                   OpenSourcer  \
# Respondent
# ...

# %%
df['Age'].median()
# Out:
# 29.0

# %%
df.fillna('us')
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
# 4                              I am a developer by profession       No
# 5                              I am a developer by profession      Yes
# ...                                                       ...      ...
# 88377                                                      us      Yes
# 88601                                                      us       No
# 88802                                                      us       No
# 88816                                                      us       No
# 88863                                                      us      Yes
#
#                                                   OpenSourcer  \
# Respondent
# ...

# %%
filt = (df['Country'] == 'India')

# %%
india_df= df.loc[filt]

# %%
india_df.head()
# Out:
#                                         MainBranch Hobbyist  \
# Respondent
# 8                      I code primarily as a hobby      Yes
# 10                  I am a developer by profession      Yes
# 15          I am a student who is learning to code      Yes
# 50                  I am a developer by profession      Yes
# 65                  I am a developer by profession      Yes
#
#                            OpenSourcer  \
# Respondent
# 8              Less than once per year
# 10          Once a month or more often
# 15                               Never
# 50          Once a month or more often
# 65                               Never
#
#                                                    OpenSource  \
# Respondent
# 8           OSS is, on average, of HIGHER quality than pro...
# 10          OSS is, on average, of HIGHER quality than pro...
# 15          OSS is, on average, of HIGHER quality than pro...
# 50          OSS is, on average, of LOWER quality than prop...
# ...

# %%
india_df.to_csv('data/indiadata')

# %%
#storing data as tsv file

# %%
india_df.to_csv('data/ind.tsv', sep='\t')

# %%
#storing data as excel file 
""" note = openpyxl is required , pip install openpyxl"""
# Out:
# ' note = openpyxl is required , pip install openpyxl'

# %%
india_df.to_excel('data/india.xlsx')

# %%
import pandas as pd
test = pd.read_excel('data/india.xlsx' , index_col='Respondent')

# %%
test
# Out:
#                                         MainBranch Hobbyist  \
# Respondent
# 8                      I code primarily as a hobby      Yes
# 10                  I am a developer by profession      Yes
# 15          I am a student who is learning to code      Yes
# 50                  I am a developer by profession      Yes
# 65                  I am a developer by profession      Yes
# ...                                            ...      ...
# 77339                                          NaN      Yes
# 79795                                          NaN      Yes
# 83862                                          NaN      Yes
# 84299                                          NaN      Yes
# 86012                                          NaN      Yes
#
#                                                   OpenSourcer  \
# Respondent
# 8                                     Less than once per year
# 10                                 Once a month or more often
# ...

# %%
india_df.to_json('data/ind.json', orient='records', lines=True)

# %%
#importing as a JSON file

# %%
test = pd.read_json('data/ind.json', orient='records', lines=True)

# %%
test
# Out:
#                                   MainBranch Hobbyist  \
# 0                I code primarily as a hobby      Yes
# 1             I am a developer by profession      Yes
# 2     I am a student who is learning to code      Yes
# 3             I am a developer by profession      Yes
# 4             I am a developer by profession      Yes
# ...                                      ...      ...
# 9056                                    None      Yes
# 9057                                    None      Yes
# 9058                                    None      Yes
# 9059                                    None      Yes
# 9060                                    None      Yes
#
#                                             OpenSourcer  \
# 0                               Less than once per year
# 1                            Once a month or more often
# 2                                                 Never
# 3                            Once a month or more often
# ...

# %%
from sqlalchemy import create_engine
import psycopg2

# %%
engine = create_engine('postgresql://dbuser:dbpass@localhost:5432/sample_db')

# %%
india_df.to_sql('sample_table', engine)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File ~/.local/lib/python3.10/site-packages/sqlalchemy/engine/base.py:3361, in Engine._wrap_pool_connect(self, fn, connection)
#    3360 try:
# -> 3361     return fn()
#    3362 except dialect.dbapi.Error as e:
#
# File ~/.local/lib/python3.10/site-packages/sqlalchemy/pool/base.py:327, in Pool.connect(self)
#     320 """Return a DBAPI connection from the pool.
#     321
#     322 The connection is instrumented such that when its
#    (...)
#     325
#     326 """
# --> 327 return _ConnectionFairy._checkout(self)
#
# File ~/.local/lib/python3.10/site-packages/sqlalchemy/pool/base.py:894, in _ConnectionFairy._checkout(cls, pool, threadconns, fairy)
#     893 if not fairy:
# --> 894     fairy = _ConnectionRecord.checkout(pool)
#     896     fairy._pool = pool
#
# ...
